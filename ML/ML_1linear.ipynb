# %%
from sklearn import linear_model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Linear Regression Single Variables

# %%
df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline 
plt.scatter(df.area, df.price, color='blue', marker='+')
plt.xlabel('area(in m)')
plt.ylabel('prices')
# Out:
# Text(0, 0.5, 'prices')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
# reg.predict(3300)

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
# y = m*x +b
135.78767123*(3300)+180616.43835616432
# Out:
# 628715.7534151643

# %%
# reg.predict(5000)

# %%
data = pd.read_csv("areas.csv")
data
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
 pred=reg.predict(data)

# %%
data['prices'] = pred

# %%
data.to_csv('prediction.csv')

# %%
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area , df.price, color='red', marker='+')
plt.plot(df.area , reg.predict(df[['area']]), color = 'black')

# %% [markdown]
# Exercise

# %%
cn = pd.read_csv("canada_per_capita_income.csv")
cn.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
# plt.xlabel('year')
# plt.ylabel('per_capita_income')
# plt.scatter(cn.year, cn.per_capita_income, color='blue')

# %%
d = pd.read_csv("homeprices.csv")
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8ea6be76e2e6> in <module>
# ----> 1 d = pd.read_csv("homeprices.csv")
#       2 d
#
# NameError: name 'pd' is not defined

# %% [markdown]
# data preprocessing

# %%
m=d.bedrooms.median()
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d73b1ee344c6> in <module>
# ----> 1 m=d.bedrooms.median()
#       2 m
#
# NameError: name 'd' is not defined

# %%
df.bedrooms.fillna(m)
# Out:
# 0    3.0
# 1    4.0
# 2    4.0
# 3    3.0
# 4    5.0
# 5    6.0
# Name: bedrooms, dtype: float64

# %%
re = linear_model.LinearRegression()
re.fit(df[['area', 'bedrooms', 'age']], df.price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-73b9f99b0a2d> in <module>
# ----> 1 re = linear_model.LinearRegression()
#       2 re.fit(df[['area', 'bedrooms', 'age']], df.price)
#
# NameError: name 'linear_model' is not defined

# %%
import sklearn
from sklearn import linear_model

# %%
re = linear_model.LinearRegression()
re.fit(df[['area', 'bedrooms', 'age']], df.price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-73b9f99b0a2d> in <module>
#       1 re = linear_model.LinearRegression()
# ----> 2 re.fit(df[['area', 'bedrooms', 'age']], df.price)
#
# NameError: name 'df' is not defined
